# %%
# %load_ext autoreload
# %autoreload 2

# %run df_transformer.py
# %run data_visualizer.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('Data/Transformed Data 2022.csv', sep=';', decimal=",")

# %%
df = clean_dataset(df)

# %%
check_week_interval(df)

# %%
hours_count = calculate_total_worked_hours(df, 'name')
visualize_dict_horiz_bar(hours_count, "Total Hours Worked per Person in 2022")

# %%
hours_count = calculate_total_worked_hours(df, 'role')
visualize_dict_pie(hours_count, "Total Hours Worked per Role in 2022")

# %%
visualize_monthly_hours(df, 'name', 2022)

# %% [markdown]
# ### Transforming DF for weekly analysis

# %%
add_column_week_length(df)
df = assign_equal_weekly_periods(df)
# Out:
# C:\Users\yassi\Desktop\Projet\WorkHoursDatasetAnalysis\df_transformer.py:184: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2022' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = new_row[col]

# %%
df.head(50)
# Out:
#     YEAR                MONTH WEEK LENGTH  (DAVID MARK, MANAGER)  \
# 0   2022              October           7                   32.0
# 1   2022              October           7                   16.0
# 2   2022              October           7                   40.0
# 3   2022              October           7                   16.0
# 4   2022   October / November           7                   12.0
# 5   2022             November           7                    8.0
# 6   2022             November           7                    8.0
# 7   2022             November           7                   12.0
# 8   2022  November / December           7                   10.0
# 9   2022             December           7                   10.0
# 10  2022             December           7                   10.0
# 11  2022             December           7                   10.0
# 12  2022             December           6                    0.0
#
# ...

# %%
visualize_weekly_total_hours(df,2022)

# %%
visualize_weekly_hours_by_role(df, 2022)

# %%
visualize_weekly_hours_by_person(df,2022)
