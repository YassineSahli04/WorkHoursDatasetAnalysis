# %%
# %load_ext autoreload
# %autoreload 2

# %run df_transformer.py
# %run data_visualizer.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from df_transformer import clean_dataset, calculate_total_worked_hours, add_column_week_length, check_week_interval
from data_visualizer import visualize_dict_horiz_bar, visualize_monthly_hours, visualize_dict_pie, visualize_weekly_total_hours, visualize_weekly_hours_by_person, visualize_weekly_hours_by_role

# %%
df = pd.read_csv('Data/Transformed Data v2.csv', sep=';', decimal=",")

# %%
df = clean_dataset(df)

# %%
check_week_interval(df)

# %%
hours_count = calculate_total_worked_hours(df, 'role')

# %%
print(hours_count)
# Out:
# {'RENE MULER': 187.0, 'GEM CASA': 42.9, 'LANDO PIASTRI': 40.0, 'DAVID MARK': 0.0}

# %%
visualize_dict_horiz_bar(hours_count, "Total Hours Worked per Person in 2024")

# %%
visualize_dict_pie(hours_count, "Total Hours Worked per Role in 2024")

# %%
visualize_monthly_hours(df, 'name')

# %%
add_column_week_length(df)

# %%
df = assign_equal_weekly_periods(df)
# Out:
# C:\Users\yassi\Desktop\Projet\WorkHoursDatasetAnalysis\df_transformer.py:151: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2024.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.

# %%
visualize_weekly_total_hours(df)

# %%
visualize_weekly_hours_by_role(df)

# %%
df.head()
# Out:
#      YEAR               MONTH WEEK LENGTH  (DAVID MARK, MANAGER)  \
# 0  2024.0             January           7                    0.0
# 1  2024.0             January           7                    0.0
# 2  2024.0             January           7                    0.0
# 3  2024.0             January           7                    0.0
# 4  2024.0  January / February           7                    0.0
#
#    (GEM CASA, ENGINEER)  (LANDO PIASTRI, ENGINEER)  (RENE MULER, DESIGNER)  \
# 0                   0.0                        0.0                    16.0
# 1                  40.0                        0.0                    40.0
# 2                   0.9                        0.0                    15.0
# 3                   0.0                        0.0                    21.0
# 4                   0.0                        0.0                    31.0
#
#    Total
# 0   16.0
# 1   80.0
# 2   15.9
# 3   21.0
# 4   31.0
