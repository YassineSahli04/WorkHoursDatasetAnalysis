# %%
# %load_ext autoreload
# %autoreload 2

# %run df_transformer.py
# %run data_visualizer.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('Data/Transformed Data 2023.csv', sep=';', decimal=",")

# %%
df = clean_dataset(df)

# %%
check_week_interval(df)

# %%
hours_count = calculate_total_worked_hours(df, 'name')
visualize_dict_horiz_bar(hours_count, "Total Hours Worked per Person in 2021")

# %%
hours_count = calculate_total_worked_hours(df, 'role')
visualize_dict_pie(hours_count, "Total Hours Worked per Role in 2021")

# %%
visualize_monthly_hours(df, 'role', 2022)

# %% [markdown]
# ### Transforming DF for weekly analysis%

# %%
add_column_week_length(df)
df = assign_equal_weekly_periods(df)
